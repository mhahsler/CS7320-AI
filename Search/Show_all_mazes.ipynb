# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# use higher resolution images in notebooks
import maze_helper as mh

# %%
import os

def list_mazes(directory):
    txt_files = []
    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            txt_files.append(filename)
    return txt_files

mazes = list_mazes(".")
#mazes = ["small_maze.txt", "medium_maze.txt", "large_maze.txt", ]

for maze_file in mazes:
    with open(maze_file, "r") as f:
        maze_str = f.read()
    maze = mh.parse_maze(maze_str)
    
    print(maze_file)
    
    mh.show_maze(maze)
# Out:
# empty_2_maze.txt
# L_maze.txt
# loops_maze.txt
# empty_maze.txt
# small_maze.txt
# large_maze.txt
# medium_maze.txt
# open_maze.txt
# wall_maze.txt
